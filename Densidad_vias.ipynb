# %% [markdown]
# # Ejercicio de Densidad de Red Vial en los cantones de C.R.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Entradas

# %% [markdown]
# ### Cantones

# %%
cantones = gpd.read_file("datos/cantones-crtm05.geojson")
cantones
# Out:
#                    gmlid cod_catalo  cod_canton          canton  \
# 0    limitecantonal_5k.1     160104         610      Corredores
# 1    limitecantonal_5k.3     160104         608       Coto Brus
# 2    limitecantonal_5k.4     160104         605             Osa
# 3    limitecantonal_5k.5     160104         603    Buenos Aires
# 4    limitecantonal_5k.6     160104         119   Pérez Zeledón
# ..                   ...        ...         ...             ...
# 79  limitecantonal_5k.82     160104         510         La Cruz
# 80  limitecantonal_5k.21     160104         601      Puntarenas
# 81  limitecantonal_5k.21     160104         612      Monteverde
# 82   limitecantonal_5k.2     160104         607         Golfito
# 83   limitecantonal_5k.2     160104         613  Puerto Jiménez
#
#                                            ori_toponi     area  cod_provin  \
# 0   Tiene su origen en el topónimo del río Corredo...   623.61           6
# ...

# %% [markdown]
# ### Red Vial

# %%
redvial = gpd.read_file("datos/redvial-crtm05.geojson")
redvial
# Out:
#      origen         categoria  codigo num_ruta jerarquia  \
# 0      CR25  CAMINO DE TIERRA  130107     None      None
# 1      CR25  CAMINO DE TIERRA  130107     None      None
# 2      CR25  CAMINO DE TIERRA  130107     None      None
# 3      CR25  CAMINO DE TIERRA  130107     None      None
# 4      CR25  CAMINO DE TIERRA  130107     None      None
# ...     ...               ...     ...      ...       ...
# 5725   CR25         AUTOPISTA  130101        1      None
# 5726   CR25         AUTOPISTA  130101       39      None
# 5727   CR25         AUTOPISTA  130101       27      None
# 5728   CR25         AUTOPISTA  130101       27      None
# 5729   CR25         AUTOPISTA  130101       32      None
#
#                                   nombre num_carril mat_supe est_supe  \
# 0                                   None       None     None     None
# 1                                   None       None     None     None
# ...

# %% [markdown]
# ### Proscesamiento

# %% [markdown]
# #### Obtención de segmentos de red vial intersecados con cantones
#
# Se genera un segmento de red vial por cada intersección con un polígono de cantón.

# %%
interseccion_redvial_cantones = gpd.overlay(redvial, cantones, how='intersection')
interseccion_redvial_cantones
# Out:
#      origen                           categoria  codigo num_ruta jerarquia  \
# 0      CR25                    CAMINO DE TIERRA  130107     None      None
# 1      CR25                    CAMINO DE TIERRA  130107     None      None
# 2      CR25                    CAMINO DE TIERRA  130107     None      None
# 3      CR25                    CAMINO DE TIERRA  130107     None      None
# 4      CR25                    CAMINO DE TIERRA  130107     None      None
# ...     ...                                 ...     ...      ...       ...
# 6613   CR25         CARRETERA PAVIMENTO UNA VIA  130103     None      None
# 6614   CR25  CARRETERA PAVIMENTO DOS VIAS O MAS  130102      129      None
# 6615   CR25  CARRETERA PAVIMENTO DOS VIAS O MAS  130102      123      None
# 6616   CR25  CARRETERA PAVIMENTO DOS VIAS O MAS  130102      119      None
# 6617   CR25  CARRETERA PAVIMENTO DOS VIAS O MAS  130102        3      None
#
# ...

# %% [markdown]
# #### Cálculo de longitud de segmentos de red vial intersecados con cantones
#
# Se calcula la longitud de cada segmento de red vial intersecado.

# %%
interseccion_redvial_cantones["longitud_redvial"] = interseccion_redvial_cantones["geometry"].length/1000

interseccion_redvial_cantones[["categoria", "codigo", "canton", "geometry", "longitud_redvial"]]
# Out:
#                                categoria  codigo  canton  \
# 0                       CAMINO DE TIERRA  130107  Pococí
# 1                       CAMINO DE TIERRA  130107  Pococí
# 2                       CAMINO DE TIERRA  130107  Pococí
# 3                       CAMINO DE TIERRA  130107  Pococí
# 4                       CAMINO DE TIERRA  130107  Pococí
# ...                                  ...     ...     ...
# 6613         CARRETERA PAVIMENTO UNA VIA  130103  Flores
# 6614  CARRETERA PAVIMENTO DOS VIAS O MAS  130102  Flores
# 6615  CARRETERA PAVIMENTO DOS VIAS O MAS  130102  Flores
# 6616  CARRETERA PAVIMENTO DOS VIAS O MAS  130102  Flores
# 6617  CARRETERA PAVIMENTO DOS VIAS O MAS  130102  Flores
#
#                                                geometry  longitud_redvial
# 0     LINESTRING (543973.130 1157346.960, 543972.520...          8.744950
# 1     LINESTRING (542005.800 1160843.730, 542304.680...          8.188802
# ...

# %% [markdown]
# #### Suma por cantón de las longitudes de los segmentos de red vial intersecados
#
# Se suman, para cada cantón, los segmentos de red vial.

# %%
# Agrupación y suma
suma_redvial_cantones = interseccion_redvial_cantones.groupby(["cod_canton","canton"])["longitud_redvial"].sum()

suma_redvial_cantones
# Out:
# cod_canton  canton
# 101         San José         100.813743
# 102         Escazú            62.935265
# 103         Desamparados     196.328451
# 104         Puriscal         455.808533
# 105         Tarrazú          295.729941
#                                ...
# 702         Pococí          1000.007878
# 703         Siquirres        589.668560
# 704         Talamanca        328.325052
# 705         Matina           306.546720
# 706         Guácimo          452.604561
# Name: longitud_redvial, Length: 84, dtype: float64

# %%
# Para convertir la serie en dataframe
suma_redvial_cantones = suma_redvial_cantones.reset_index()

suma_redvial_cantones
# Out:
#     level_0  index  cod_canton        canton  longitud_redvial
# 0         0      0         101      San José        100.813743
# 1         1      1         102        Escazú         62.935265
# 2         2      2         103  Desamparados        196.328451
# 3         3      3         104      Puriscal        455.808533
# 4         4      4         105       Tarrazú        295.729941
# ..      ...    ...         ...           ...               ...
# 79       79     79         702        Pococí       1000.007878
# 80       80     80         703     Siquirres        589.668560
# 81       81     81         704     Talamanca        328.325052
# 82       82     82         705        Matina        306.546720
# 83       83     83         706       Guácimo        452.604561
#
# [84 rows x 5 columns]

# %% [markdown]
# ### Cálculo de la densidad de la red vial por cantón

# %%
# Se le agrega a la capa de cantones la longitud de la red vial para cada polígono
cantones_redvial = cantones.merge(suma_redvial_cantones, on="cod_canton")

# Se calcula el área del cantón
cantones_redvial["area_canton"] = cantones_redvial["geometry"].area/1000000

# Se calcula la densidad
cantones_redvial["densidad_redvial"] = cantones_redvial["longitud_redvial"] / cantones_redvial["area_canton"]

cantones_redvial.sort_values(by="densidad_redvial", ascending=False)
# Out:
#                    gmlid cod_catalo  cod_canton            canton_x  \
# 29  limitecantonal_5k.32     160104         101            San José
# 35  limitecantonal_5k.38     160104         108          Goicoechea
# 27  limitecantonal_5k.30     160104         118          Curridabat
# 36  limitecantonal_5k.39     160104         113               Tibás
# 11  limitecantonal_5k.13     160104         120  León Cortés Castro
# ..                   ...        ...         ...                 ...
# 2    limitecantonal_5k.4     160104         605                 Osa
# 25  limitecantonal_5k.28     160104         701               Limón
# 83   limitecantonal_5k.2     160104         613      Puerto Jiménez
# 48  limitecantonal_5k.51     160104         401             Heredia
# 6    limitecantonal_5k.8     160104         704           Talamanca
#
#                                            ori_toponi     area  cod_provin  \
# ...

# %% [markdown]
# ## Salida

# %% [markdown]
# ### Mapa de coropletas de densidad de red vial en cantones

# %%
cantones_redvial.plot(column="densidad_redvial",
                      legend=True,
                      cmap='Blues', 
                      edgecolor="black",
                      scheme='quantiles',
                      figsize=(10, 10))
# Out:
# <AxesSubplot: >
